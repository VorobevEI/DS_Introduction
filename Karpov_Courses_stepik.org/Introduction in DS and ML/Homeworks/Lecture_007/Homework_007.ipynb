# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree

from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('C:/Users/9/Downloads/songs.csv')

# %%
df.head(10)
# Out:
#                           song  year          artist    genre  \
# 0                   the-ownerz  2007       gangstarr  Hip-Hop
# 1         dead-sound-of-misery  2006  blind-guardian    Metal
# 2                modred-s-song  2006  blind-guardian    Metal
# 3               the-ninth-wave  2015  blind-guardian    Metal
# 4                       skills  2014       gangstarr  Hip-Hop
# 5  werdz-from-the-ghetto-child  2007       gangstarr  Hip-Hop
# 6      givin-a-little-bit-more  2006            abba      Pop
# 7        nina-pretty-ballerina  2006            abba      Pop
# 8       don-t-break-the-circle  2007  blind-guardian    Metal
# 9         the-name-of-the-game  2001            abba      Pop
#
#                                               lyrics  length  commas  \
# 0  "One-two.."\n"One-two, shots to the chin.. kno...    1300      24
# 1  It's dark\nLet's do it now\nBring in the siren...    1566       0
# 2  I've lost my battle before it starts\nmy first...     996       1
# ...

# %%
df.describe()
# Out:
#               year       length      commas  exclamations      colons  \
# count   360.000000   360.000000  360.000000    360.000000  360.000000
# mean   2005.388889  1740.452778   16.002778      0.502778    0.269444
# std       6.891834   950.442338   17.271146      2.431225    1.128096
# min    1977.000000    29.000000    0.000000      0.000000    0.000000
# 25%    2006.000000  1027.000000    3.000000      0.000000    0.000000
# 50%    2006.000000  1514.500000   10.000000      0.000000    0.000000
# 75%    2008.000000  2266.750000   23.000000      0.000000    0.000000
# max    2016.000000  5280.000000  100.000000     35.000000   13.000000
#
#           hyphens
# count  360.000000
# mean     3.288889
# std      8.760502
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      3.000000
# max     63.000000

# %%
df.artist.unique()
# Out:
# array(['gangstarr', 'blind-guardian', 'abba'], dtype=object)

# %%
df_train=df.iloc[:270, :]

# %%
df_train
# Out:
#                      song  year          artist    genre  \
# 0              the-ownerz  2007       gangstarr  Hip-Hop
# 1    dead-sound-of-misery  2006  blind-guardian    Metal
# 2           modred-s-song  2006  blind-guardian    Metal
# 3          the-ninth-wave  2015  blind-guardian    Metal
# 4                  skills  2014       gangstarr  Hip-Hop
# ..                    ...   ...             ...      ...
# 265        into-the-storm  2006  blind-guardian    Metal
# 266    blowin-up-the-spot  2006       gangstarr  Hip-Hop
# 267            discipline  2007       gangstarr  Hip-Hop
# 268         peace-of-mine  2007       gangstarr  Hip-Hop
# 269         turn-the-page  2006  blind-guardian    Metal
#
#                                                 lyrics  length  commas  \
# 0    "One-two.."\n"One-two, shots to the chin.. kno...    1300      24
# 1    It's dark\nLet's do it now\nBring in the siren...    1566       0
# ...

# %%
df_test=df.iloc[270:, :]

# %%
df_test
# Out:
#                       song  year          artist    genre  \
# 270             discipline  2008       gangstarr  Hip-Hop
# 271  gracias-por-la-musica  2006            abba      Pop
# 272           cause-effect  2006       gangstarr  Hip-Hop
# 273       out-on-the-water  2006  blind-guardian    Metal
# 274        miracle-machine  2015  blind-guardian    Metal
# ..                     ...   ...             ...      ...
# 355         just-like-that  2006            abba      Pop
# 356              ring-ring  1995            abba      Pop
# 357         reina-danzante  1981            abba      Pop
# 358    code-of-the-streets  2006       gangstarr  Hip-Hop
# 359              one-of-us  2001            abba      Pop
#
#                                                 lyrics  length  commas  \
# 270  Mmm\nYou gotta hold your head up..\nOahh-eahh-...    4431      48
# 271  Agnetha: Soy muy sencilla\nwhy algo aburrida t...    1325      19
# ...

# %%
df_val=df_train.iloc[202:, :]

# %%
df_val
# Out:
#                           song  year          artist    genre  \
# 202            love-isn-t-easy  2001            abba      Pop
# 203  words-from-the-nutcracker  2006       gangstarr  Hip-Hop
# 204                barbara-ann  2006  blind-guardian    Metal
# 205  conociendome-conociendote  2007            abba      Pop
# 206                 the-wizard  2006  blind-guardian    Metal
# ..                         ...   ...             ...      ...
# 265             into-the-storm  2006  blind-guardian    Metal
# 266         blowin-up-the-spot  2006       gangstarr  Hip-Hop
# 267                 discipline  2007       gangstarr  Hip-Hop
# 268              peace-of-mine  2007       gangstarr  Hip-Hop
# 269              turn-the-page  2006  blind-guardian    Metal
#
#                                                 lyrics  length  commas  \
# 202  Do you remember the first time\nAnd all of you...    1549      24
# 203  Sick thoughts on my mind, with no self-control...     840      20
# ...

# %%
df_train=df_train.iloc[:202, :]

# %%
df_train
# Out:
#                        song  year          artist    genre  \
# 0                the-ownerz  2007       gangstarr  Hip-Hop
# 1      dead-sound-of-misery  2006  blind-guardian    Metal
# 2             modred-s-song  2006  blind-guardian    Metal
# 3            the-ninth-wave  2015  blind-guardian    Metal
# 4                    skills  2014       gangstarr  Hip-Hop
# ..                      ...   ...             ...      ...
# 197  carry-the-blessed-home  2006  blind-guardian    Metal
# 198        you-re-the-voice  2010  blind-guardian    Metal
# 199               so-wassup  2008       gangstarr  Hip-Hop
# 200               jfk-2-lax  2008       gangstarr  Hip-Hop
# 201              angel-eyes  2001            abba      Pop
#
#                                                 lyrics  length  commas  \
# 0    "One-two.."\n"One-two, shots to the chin.. kno...    1300      24
# 1    It's dark\nLet's do it now\nBring in the siren...    1566       0
# ...

# %%
X_train = df_train.drop(['song', 'year', 'artist', 'genre', 'lyrics'], axis=1)

# %%
X_train
# Out:
#      length  commas  exclamations  colons  hyphens
# 0      1300      24             5       0       11
# 1      1566       0             0       0        0
# 2       996       1             0       1        0
# 3      2868       5             0       0        0
# 4      3351      22             0       0        3
# ..      ...     ...           ...     ...      ...
# 197    1374       7             1       0        0
# 198    1542      18             0       0       60
# 199    2236      34             1       0       13
# 200    3195      39             1       1        2
# 201    1520       8             0       0        6
#
# [202 rows x 5 columns]

# %%
y_train=df_train.artist

# %%
y_train
# Out:
# 0           gangstarr
# 1      blind-guardian
# 2      blind-guardian
# 3      blind-guardian
# 4           gangstarr
#             ...
# 197    blind-guardian
# 198    blind-guardian
# 199         gangstarr
# 200         gangstarr
# 201              abba
# Name: artist, Length: 202, dtype: object

# %%
X_val = df_val.drop(['song', 'year', 'artist', 'genre', 'lyrics'], axis=1)
y_val=df_val.artist	

X_test = df_test.drop(['song', 'year', 'artist', 'genre', 'lyrics'], axis=1)
y_test=df_test.artist

# %%
X_val
# Out:
#      length  commas  exclamations  colons  hyphens
# 202    1549      24             0       0        0
# 203     840      20             0       0        1
# 204    1195       5             0       0        6
# 205     647      15             0       0        0
# 206     714       0             0       0        0
# ..      ...     ...           ...     ...      ...
# 265     896       0             0       0        0
# 266    1886      34             0       0        5
# 267    4431      48             0       0       29
# 268    2753      39             4       0        3
# 269    1625      12             2       1        0
#
# [68 rows x 5 columns]

# %%
y_val
# Out:
# 202              abba
# 203         gangstarr
# 204    blind-guardian
# 205              abba
# 206    blind-guardian
#             ...
# 265    blind-guardian
# 266         gangstarr
# 267         gangstarr
# 268         gangstarr
# 269    blind-guardian
# Name: artist, Length: 68, dtype: object

# %%
X_test
# Out:
#      length  commas  exclamations  colons  hyphens
# 270    4431      48             0       0       29
# 271    1325      19             3       7        0
# 272    3085      47             2       0        4
# 273     134       0             0       0        0
# 274    1233       9             0       0        0
# ..      ...     ...           ...     ...      ...
# 355     972       2             0       0        1
# 356    1283      33             0       0        3
# 357     810       1             0       0        0
# 358    1996      34             0       0        5
# 359     991       8             0       0        0
#
# [90 rows x 5 columns]

# %%
y_test
# Out:
# 270         gangstarr
# 271              abba
# 272         gangstarr
# 273    blind-guardian
# 274    blind-guardian
#             ...
# 355              abba
# 356              abba
# 357              abba
# 358         gangstarr
# 359              abba
# Name: artist, Length: 90, dtype: object

# %%
clf = tree.DecisionTreeClassifier(criterion='entropy', max_depth = 16)

# %%
clf.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': None,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'presort': 'deprecated',
#  'random_state': None,
#  'splitter': 'best'}

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
clf.score(X_val, y_val)
# Out:
# 0.6323529411764706

# %%
y_test_model = clf.predict(X_test)

# %%
y_test_model
# Out:
# array(['gangstarr', 'abba', 'gangstarr', 'blind-guardian', 'abba',
#        'blind-guardian', 'blind-guardian', 'abba', 'blind-guardian',
#        'gangstarr', 'gangstarr', 'gangstarr', 'blind-guardian',
#        'gangstarr', 'blind-guardian', 'abba', 'abba', 'blind-guardian',
#        'gangstarr', 'blind-guardian', 'abba', 'gangstarr', 'abba',
#        'gangstarr', 'abba', 'gangstarr', 'blind-guardian',
#        'blind-guardian', 'blind-guardian', 'gangstarr', 'blind-guardian',
#        'gangstarr', 'blind-guardian', 'blind-guardian', 'abba',
#        'blind-guardian', 'blind-guardian', 'gangstarr', 'gangstarr',
#        'gangstarr', 'gangstarr', 'gangstarr', 'abba', 'abba',
#        'blind-guardian', 'gangstarr', 'gangstarr', 'abba', 'abba',
#        'blind-guardian', 'gangstarr', 'blind-guardian', 'blind-guardian',
#        'blind-guardian', 'gangstarr', 'abba', 'abba', 'gangstarr',
#        'gangstarr', 'gangstarr', 'blind-guardian', 'gangstarr',
# ...

# %%
from sklearn.metrics import precision_score

# %%
precision_score(y_test, y_test_model, average='micro')
# Out:
# 0.7444444444444445
