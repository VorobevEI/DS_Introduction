# %%
#Importing libraries for workflow
#Importer des bibliotheques pour le flux de travail
#Импорт библиотек для работы

import pandas as pd
import numpy as np

# %%
#Loading data frame into sp (Students Performance)
#Chargement de la trame de donnees dans sp
#Загрузка данных в переменную sp

sp = pd.read_csv('C:/Users/ei_vorobev/Desktop/KC/StudentsPerformance.csv')

# %%
#Show the first 10 lines
#Afficher les 10 premieres lignes
#Показать 10 первых строк

sp.head(10)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
# 9  female        group B                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# ...

# %%
#Show the last 15 lines
#Afficher les 15 dernieres lignes
#Показать 15 последних строк

sp.tail(15)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 985    male        group A                 high school      standard
# 986  female        group C          associate's degree      standard
# 987    male        group E            some high school      standard
# 988  female        group A            some high school  free/reduced
# 989  female        group D                some college  free/reduced
# 990    male        group E                 high school  free/reduced
# 991  female        group B            some high school      standard
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# ...

# %%
#Descripting numeric data
#Description des donnees numeriques
#Описание числовых данных

sp.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
#Descripting data types
#Description des types de donnees
#Описание типов данных

sp.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
#Data frame size
#Taille de la trame de donnees
#Размер датафрейма

sp.shape
# Out:
# (1000, 8)

# %%
#Calculating mean writing score in each gender group
#Calculation le score moyen d'ecriture dans chaque groupe de genre
#Рассчет среднего результата по письменному заданию в каждой гендерной группе

sp.groupby('gender').aggregate({'writing score' : 'mean'})
# Out:
#         writing score
# gender
# female      72.467181
# male        63.311203

# %%
#Number of attributes
#Nombre d'attributs
#Количество атрибутов

sp.size
# Out:
# 8000

# %%
#Selecting the attributes of the 3 first rows and the first 5 columns
#Selection des attributs des 3 premieres lignes et des 5 premieres colonnes
#Выбор атрибутов первых 3 строк и первых 5 столбцов

sp.iloc[0:3, 0:5]
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
#
#   test preparation course
# 0                    none
# 1               completed
# 2                    none

# %%
#Selecting the attributes of 3,6,10 rows and 4,6, second from the end of colomns
#Selection des attributs des 3,6,10 lignes et 4,6, deuxxieme a partir de la fin des colonnes
#Выбор атрибутов 3,6,10 строк и 4,6 и второго с конца столбцов

sp.iloc[[2, 5, 9], [3, 5, -2]]
# Out:
#           lunch  reading score  reading score
# 2      standard             95             95
# 5      standard             83             83
# 9  free/reduced             60             60

# %%
#Creating a new data frame
#Creation une nouveau trame de donnees
#Создание нового датафрейма

sp_with_names=sp.iloc[[1,3,6,9,12]]

# %%
sp_with_names
# Out:
#     gender race/ethnicity parental level of education         lunch  \
# 1   female        group C                some college      standard
# 3     male        group A          associate's degree  free/reduced
# 6   female        group B                some college      standard
# 9   female        group B                 high school  free/reduced
# 12  female        group B                 high school      standard
#
#    test preparation course  math score  reading score  writing score
# 1                completed          69             90             88
# 3                     none          47             57             44
# 6                completed          88             95             92
# 9                     none          38             60             50
# 12                    none          65             81             73

# %%
sp_with_names.index = ['Jack Sparrow', 'Luke Skywalker', 'Iron Man', 'Shrek', 'Jon Snow']

# %%
sp_with_names
# Out:
#                 gender race/ethnicity parental level of education  \
# Jack Sparrow    female        group C                some college
# Luke Skywalker    male        group A          associate's degree
# Iron Man        female        group B                some college
# Shrek           female        group B                 high school
# Jon Snow        female        group B                 high school
#
#                        lunch test preparation course  math score  \
# Jack Sparrow        standard               completed          69
# Luke Skywalker  free/reduced                    none          47
# Iron Man            standard               completed          88
# Shrek           free/reduced                    none          38
# Jon Snow            standard                    none          65
#
#                 reading score  writing score
# Jack Sparrow               90             88
# Luke Skywalker             57             44
# ...

# %%
sp_with_names.loc[['Jack Sparrow', 'Iron Man'], ['gender', 'math score', 'reading score']]
# Out:
#               gender  math score  reading score
# Jack Sparrow  female          69             90
# Iron Man      female          88             95

# %%
sp_with_names.iloc[:, 0]
# Out:
# Jack Sparrow      female
# Luke Skywalker      male
# Iron Man          female
# Shrek             female
# Jon Snow          female
# Name: gender, dtype: object

# %%
type(sp_with_names.iloc[:, 0])
# Out:
# pandas.core.series.Series

# %%
first_series=pd.Series([1, 2, 3], index = ['Jack Sparrow', 'Luke Skywalker', 'Iron Man'])
second_series=pd.Series([4, 5, 6], index = ['Jack Sparrow', 'Luke Skywalker', 'Iron Man'])

# %%
pd.DataFrame({'col_name_1': first_series, 'col_name_2': second_series})
# Out:
#                 col_name_1  col_name_2
# Jack Sparrow             1           4
# Luke Skywalker           2           5
# Iron Man                 3           6

# %%
sp_with_names['gender']
# Out:
# Jack Sparrow      female
# Luke Skywalker      male
# Iron Man          female
# Shrek             female
# Jon Snow          female
# Name: gender, dtype: object

# %%
sp_with_names[['gender']]
# Out:
#                 gender
# Jack Sparrow    female
# Luke Skywalker    male
# Iron Man        female
# Shrek           female
# Jon Snow        female

# %%
sp_with_names[['gender']].shape
# Out:
# (5, 1)

# %%
sp_with_names['gender'].shape
# Out:
# (5,)
